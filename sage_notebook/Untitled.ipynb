# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft
# from scipy.io import wavfile # get the api
import wave
import matplotlib.animation as animation

# %%
original = wave.open('audios/original/darude-sandstorm.wav') # load the data
decrypted = wave.open('audios/decrypted/darude-sandstorm_wrong.wav') # load the data

# %%
original.getparams()
# Out:
# _wave_params(nchannels=1, sampwidth=2, framerate=44100, nframes=1417374, comptype='NONE', compname='not compressed')

# %%
decrypted.getparams()
# Out:
# _wave_params(nchannels=1, sampwidth=2, framerate=44100, nframes=7208100, comptype='NONE', compname='not compressed')

# %%
n_frames = file.getnframes()
s_rate = file.getframerate()
duration = 1 / s_rate
n = n_frames // s_rate

# %%
n_frames_wrong = decrypted.getnframes()
s_rate_wrong = decrypted.getframerate()
duration_wrong = 1 / s_rate_wrong
n = n_frames_wrong // s_rate_wrong

# %%
file.rewind()
data = file.readframes(-1)

# %%
wav_data = np.frombuffer(data, np.int16)

# %%
ts = np.arange(0, n_frames/s_rate, duration)

# %%
fft_data = fft(wav_data)
fft_data = abs(fft_data[:len(fft_data) // 2]) / max(abs(fft_data[:len(fft_data) // 2]))

# %%
plt.plot(ts, wav_data)
plt.show()

# %%
plt.semilogx(fft_data)

# %%
decrypted.rewind()
data_wrong = decrypted.readframes(-1)

# %%
wav_data_wrong = np.frombuffer(data_wrong, np.int16)

# %%
ts_wrong = np.arange(0, n_frames_wrong/s_rate_wrong, duration_wrong)

# %%
fft_data_wrong = fft(wav_data_wrong)
fft_data_wrong = abs(fft_data_wrong[:len(fft_data_wrong) // 2]) / max(abs(fft_data_wrong[:len(fft_data_wrong) // 2]))

# %%
plt.plot(ts_wrong, wav_data_wrong)
plt.show()

# %%
fft_data_wrong
# Out:
# array([1.00000000e+00, 5.19393019e-04, 1.20469575e-03, ...,
#        4.76585022e-04, 1.39781516e-03, 1.39300541e-03])

# %%
plt.semilogx(fft_data_wrong[1:])

# %%
titulos = ['Tempo (áudio certo)', 'Tempo (áudio errado)', 'Frequência (áudio certo)', 'Frequência (áudio errado)']
titles = ['Time (right audio)', 'Time (wrong audio)', 'Frequency (right audio)', 'Frequency (wrong audio)']

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(ncols = 2, nrows = 2, figsize=(10,10))

axs = [ax1, ax2, ax3, ax4]

for i, ax in enumerate(axs):
    ax.set_title(titulos[i])
    
ax1.plot(ts, wav_data)
ax2.plot(ts_wrong, wav_data_wrong)

ax3.semilogx(fft_data)
ax4.semilogx(fft_data_wrong[1:])

fig.savefig('audio_graphs_ptbr.png')

# %%
f.save
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-3b41e8240dc5> in <module>
# ----> 1 fig.save('audio_graphs_en.png')
#
# AttributeError: 'Figure' object has no attribute 'save'

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(ncols = 2, nrows = 2, figsize=(10,10))
