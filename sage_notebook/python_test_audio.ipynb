# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio
import struct
import librosa.display
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-100-5dca1a483fba> in <module>()
#       3 from IPython.display import Audio
#       4 import struct
# ----> 5 import librosa.display
#
# ModuleNotFoundError: No module named 'librosa'

# %%
# from functions import *

# %%
import wave

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-a717194031d5> in <module>()
# ----> 1 np.linspace(0, 0.5, 4800 * 0.5)
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# /home/thaig/anaconda3/envs/sage/lib/python3.7/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     111
#     112     """
# --> 113     num = operator.index(num)
#     114     if num < 0:
#     115         raise ValueError("Number of samples, %s, must be non-negative." % num)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
pitchStandard = 440
a = 2 ** (1/12)
majorScale = [0, 2, 4, 5, 7, 9, 11, 12]

# %%
data[1]
# Out:
# 0.05756522490866663

# %%
# Out:
# 48000

# %%
# Generate a sound
framerate = 48000
duration = 1
ts = np.linspace(0,duration, int(framerate * duration))
volume = np.linspace(0, )
data = []
for note in majorScale:
    data += [volume * np.sin(a ** note * 440 * 2 * np.pi* t) for t in ts]
for note in list(reversed(majorScale))[1:]:
    data += [volume * np.sin(a ** note * 440 * 2 * np.pi* t) for t in ts]
# data = [volume * np.sin(440 * 2 * np.pi * t) for t in ts] + [volume * np.sin(540 * 2 * np.pi * t) for t in ts]
# data = []
# for i, t in enumerate(ts):
    
# data = np.sin(2*np.pi*220*ts)
Audio(data,rate=framerate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(data[::len(ts) + 1])

# %%
# audio = wave.open('audio/teste.wav')

# %%
# N = 168
# xs = np.arange(N)
# ys = []
# for x in xs:
#     y1 = 4 / np.pi * np.sin(2 * np.pi * x / N)
#     y2 = 4 / (3 * np.pi) * np.sin(6 * np.pi * x / N)    
#     y3 = 4 / (5 * np.pi) * np.sin(10 * np.pi * x / N)
#     ys.append(y1 + y2 + y3)
# ys *= 300
# xs = np.arange(300 * N)

# %%
# plt.plot(xs, ys)
# plt.show()

# %%
p
# Out:
# 6864797660130609714981900799081393217269435300143305409394463459185543183397656052122559640661454554977296311391480858037121987999716643812574028291115057151

# %%
# %%time
p = 2 ** 521 - 1
# proof.arithmetic(False)
F = GF(p)
A = p-3
B = 1093849038073734274511112390766805569936207598951683748994586394495953116150735016013708737573759623248592132296706313309438452531591012912142327488478985984
E = EllipticCurve([F(A), F(B)])
q = E.cardinality()
# Out:
# CPU times: user 250 ms, sys: 0 ns, total: 250 ms
# Wall time: 250 ms

# %%
import wave

# %%
audio = wave.open('audio/test.wav')

# %%
data = audio.readframes(audio.getnframes())

# %%
# %%time
P = base_point(E)
print(u'O ponto base é: ')
print(P)
# Out:
# O ponto base é:
# (6862997142151195955189879864170995909379486831464590158551229711443194011808391025647843517145778736414007965388585360761602304770778969030753013735336028118 : 3992566807823493054471288072009313680097427850022798909704163442903777548418418687166434505631095314823558641657119678062857206475916822772098297185442776168 : 1)

# %%
# %%time
alice_keys = generate_keys(E, P)

print(u'Chave Privada (Alice): %s \n \n' %(alice_keys[0]))
print(u'Chave Pública (Alice):')
print(alice_keys[1])
print('\n')
# Out:
# Chave Privada (Alice): 5771119351603839915082006952957921626858315345089023131425050358073616276454359505094012232649930775550607231716782563230783055742628004254200319820087652929
#
#
# Chave Pública (Alice):
# (5544773138592234052723354572289399086864847507013069428724837024786263844976895044707607663350719217089783838049862537935300439734098667171927025686919192565 : 2927265368830668953032356055700660743465230817021715218561364274410237370342647680531783396790146519756499200834040950529482296117683279710417979798009921971 : 1)

# %%
# %%time
bob_keys = generate_keys(E, P)

print(u'Chave Privada (Bob): %s \n \n' %(bob_keys[0]))
print(u'Chave Pública (Bob):')
print(bob_keys[1])
print('\n')
# Out:
# Chave Privada (Bob): 1594343463636388229168654718437936241938793926212039858425925294202328300338455140187121162599268683550284818240688947019803395247252865179590861748692499984
#
#
# Chave Pública (Bob):
# (4883644942121106372138014001077512786402364072201761924241303966075320700263805489231254262210684004669098292673121734131817194751832240819473662955480246101 : 6407213184335229914772282165248806176863779058475785178349584840420106056045633962740655524371180820277693827632888611185801592800687704400640118725535157038 : 1)

# %%
len(data) // 128
# Out:
# 16764

# %%
# %%time
enc_data = encode(E, P, str(data), alice_keys[0], alice_keys[1],bob_keys[1])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-b435204f0b2d> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'enc_data = encode(E, P, str(data), alice_keys[0], alice_keys[1],bob_keys[1])')
#
# /home/thaig/anaconda3/envs/sage/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /home/thaig/anaconda3/envs/sage/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /home/thaig/anaconda3/envs/sage/lib/python3.7/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# /mnt/c/Users/thaig/Documents/GitHub/ecc/sage_notebook/functions.py in encode(E, P, msg, privateKey_sender, publicKey_sender, publicKey_reciever)
#      81         k = ZZ.random_element(q)
#      82         kP = k *  publicKey_sender
# ---> 83         enc_msg.append([kP, Q + k * privateKey_sender * publicKey_reciever])
#      84 #     enc_msg = [kP, PM + k * privateKey_sender * publicKey_reciever]
#      85     return enc_msg
#
# /home/thaig/anaconda3/envs/sage/lib/python3.7/site-packages/sage/rings/integer.pyx in sage.rings.integer.Integer.__mul__ (build/cythonized/sage/rings/integer.c:13834)()
#    1998             return y
#    1999
# -> 2000         return coercion_model.bin_op(left, right, operator.mul)
#    2001
#    2002     cpdef _mul_(self, right):
#
# /home/thaig/anaconda3/envs/sage/lib/python3.7/site-packages/sage/structure/coerce.pyx in sage.structure.coerce.CoercionModel.bin_op (build/cythonized/sage/structure/coerce.c:10056)()
#    1199         if action is not None:
#    1200             if (<Action>action)._is_left:
# -> 1201                 return (<Action>action)._act_(x, y)
#    1202             else:
#    1203                 return (<Action>action)._act_(y, x)
#
# /home/thaig/anaconda3/envs/sage/lib/python3.7/site-packages/sage/structure/coerce_actions.pyx in sage.structure.coerce_actions.IntegerMulAction._act_ (build/cythonized/sage/structure/coerce_actions.c:9525)()
#     759             return fast_mul_long(a, n_long)
#     760
# --> 761         return fast_mul(a, nn)
#     762
#     763     def _repr_name_(self):
#
# /home/thaig/anaconda3/envs/sage/lib/python3.7/site-packages/sage/structure/coerce_actions.pyx in sage.structure.coerce_actions.fast_mul (build/cythonized/sage/structure/coerce_actions.c:10611)()
#     887     while n != 0:
#     888         sig_check()
# --> 889         pow2a += pow2a
#     890         if n & 1:
#     891             sum += pow2a
#
# /home/thaig/anaconda3/envs/sage/lib/python3.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__add__ (build/cythonized/sage/structure/element.c:10803)()
#    1229         cdef int cl = classify_elements(left, right)
#    1230         if HAVE_SAME_PARENT(cl):
# -> 1231             return (<Element>left)._add_(right)
#    1232         # Left and right are Sage elements => use coercion model
#    1233         if BOTH_ARE_ELEMENT(cl):
#
# /home/thaig/anaconda3/envs/sage/lib/python3.7/site-packages/sage/structure/element.pyx in sage.structure.element.ModuleElement._add_ (build/cythonized/sage/structure/element.c:15174)()
#    2344     Generic element of a module.
#    2345     """
# -> 2346     cpdef _add_(self, other):
#    2347         """
#    2348         Abstract addition method
#
# /home/thaig/anaconda3/envs/sage/lib/python3.7/site-packages/sage/schemes/elliptic_curves/ell_point.py in _add_(self, right)
#     660         if x1 == x2 and y1 == y2:
#     661             try:
# --> 662                 m = (3*x1*x1 + 2*a2*x1 + a4 - a1*y1) / (2*y1 + a1*x1 + a3)
#     663             except ZeroDivisionError:
#     664                 R = E.base_ring()
#
# KeyboardInterrupt:

# %%
fout_write = wave.open("testing.wav", "w")
fout_write.setnchannels(1)
fout_write.setsampwidth(2)
fout_write.setframerate(44100)
fout_write.setcomptype('NONE', 'Not Compressed')
BinStr = b""
for i in range(len(ys)):
    BinStr = BinStr + struct.pack('h', int(round(ys[i] * 20000)))

# %%
'h', round(ys[i] * 20000)
# Out:
# ('h', -2849.0)

# %%
fout_write.writeframesraw(BinStr)

# %%
fout_write.close()

# %%
fout_read = wave.open('testing.wav')
bits = fout_read.readframes(fout_read.getnframes())
